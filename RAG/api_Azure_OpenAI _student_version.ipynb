# %% [markdown]
# # Import

# %%
# !pip install requests

# %%
import requests
from dotenv import load_dotenv
import os
from pathlib import Path

# Charge les variables d'environnement depuis le fichier .env
env_path = Path('/Users/julesbesson/Documents/Projet_EY/Projet_EY/RAG/.env')  # Fichier .env est dans le dossier parent
load_dotenv(dotenv_path=env_path)
# Out:
# True

# %% [markdown]
# # URL et Users

# %%
# Accéder à la variable d'environnement
base_url = os.getenv("BASE_URL")
auth_user = os.getenv("AUTH_USER")
auth_password = os.getenv("AUTH_PASSWORD")

auth = (auth_user, auth_password)

# %% [markdown]
# # Test d'accès + login

# %%
response = requests.get(base_url)
print(response.json().get('message'))
# Out:
# Bienvenue sur le web service pour intéragir avec l'API OpenAI

# %%
login_url = base_url + "/login"

response = requests.post(login_url, auth = auth)
print(f"Reponse : {response.content}")

token= response.json().get('token')
print(token)

headers = {'Authorization': token}
print(headers)
# Out:
# Reponse : b'{"token":"eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VybmFtZSI6InVzZXIiLCJleHAiOjE3MzcwOTYzMjR9.8Eg4dWOqmRGzjtKYA2vZX8e2ns8QTmjW18c_RfWYyFE"}\n'
# eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VybmFtZSI6InVzZXIiLCJleHAiOjE3MzcwOTYzMjR9.8Eg4dWOqmRGzjtKYA2vZX8e2ns8QTmjW18c_RfWYyFE
# {'Authorization': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VybmFtZSI6InVzZXIiLCJleHAiOjE3MzcwOTYzMjR9.8Eg4dWOqmRGzjtKYA2vZX8e2ns8QTmjW18c_RfWYyFE'}

# %% [markdown]
# # Liste Model

# %%
list_url = base_url + "/model_completion"

response = requests.get(list_url, headers = headers)
print(f"Reponse : {response.content.decode('utf-8')}")
# Out:
# Reponse : {"completion":["gpt-4o-mini","gpt-4o","gpt-4-turbo-ga","gpt-4-turbo","gpt-4-32k","gpt-4","gpt-35-turbo-16k","gpt-35-turbo"]}

# %%
list_url = base_url + "/model_embedding"

response = requests.get(list_url, headers = headers)
print(f"Reponse : {response.content.decode('utf-8')}")
# Out:
# Reponse : {"embedding":["text-embedding-3-large","text-embedding-ada-002"]}

# %% [markdown]
# # Completion

# %%
completion_url = base_url + "/completions"

data = {
    'model': 'gpt-4o',
    'prompt': 'Qui a gagné la coupe du monde 2018 en Foot ?',
    'max_tokens': 100,
    'temperature' : 1
}

response = requests.post(completion_url, json = data, headers=headers)
response_text = response.content.decode('utf-8')
print(f"Reponse : {response_text}")
# Out:
# Reponse : La Coupe du Monde de football 2018 a été remportée par l'équipe de France. Ils ont battu la Croatie en finale avec un score de 4-2.

# %% [markdown]
# # embeddings

# %%
embeddings_url = base_url + "/embeddings/single_text"

data = {
    'model' : "text-embedding-ada-002",
    'text': "hello"
}

requests.post(embeddings_url, json=data, headers=headers).content.decode('utf-8')
# Out:
# '[-0.025046451, -0.019402739, -0.027782395, -0.031033808, -0.024649937, 0.02743875, -0.012470357, -0.008498611, -0.017433388, -0.008465569, 0.03254056, 0.0042757397, -0.024583852, -0.0006298786, 0.014129106, -0.0015034479, 0.039387032, 0.002009003, 0.02684398, -0.012569485, -0.021015229, 0.008881908, 0.008445743, -0.0030630685, -0.0053628483, -0.009503112, 0.011069342, -0.0016967483, 0.0034529737, -0.023235705, 0.0067308205, -0.00790384, -0.023922995, -0.008901733, 0.006839862, -0.013679724, 0.009503112, -0.014115889, 0.021768603, -0.0105737, 0.0034133224, -0.014591705, 0.005243894, -0.014935351, -0.031879704, 0.016243845, -0.0054388465, -0.0066713435, -0.009661718, 0.034787472, 0.026315294, 0.00923877, -0.019614212, -0.0080029685, -0.0056602336, -0.005732928, -0.0136532895, 0.006162484, 0.0009260248, -0.038594004, -0.0004161329, 0.018993007, -0.01539795, 0.018728666, -0.00037792715, 0.010851259, 0.019085528, 0.0040576574, -0.004718513, 0.022085816, 0.025152188, 0.01732765, 0.0068861
# ...

# %%
embeddings_url = base_url + "/embeddings/single_text"

data = {
    'text': 'hello',
    'model' : 'text-embedding-3-large'
}

requests.post(embeddings_url, json=data, headers=headers).content.decode('utf-8')
# Out:
# '[-0.024605071, -0.007548185, 0.004001545, 0.006006343, 0.0051005604, 0.00025600928, -0.006396835, 0.05249511, 0.0096375225, 0.056553017, -0.0044041146, -0.021223484, -0.021626053, -0.010378252, -0.017841898, 0.020176802, 0.024073679, 0.005958034, 0.015080268, -0.011932171, 0.010627845, -0.00812386, 0.001116125, 0.035071887, 0.010040093, 0.031239422, -0.020837016, -0.017262196, -0.049338963, -0.033751458, 0.0008765959, 0.026311968, 0.0019091876, 0.019097915, 0.03555497, 0.0071415897, 0.026585715, 0.0044041146, -0.023864342, 0.02241509, 0.02673064, 0.008719664, -0.024460146, -0.0020893377, -0.001611286, -0.0018679242, 0.012318638, 0.023413464, 0.015281552, 0.003939146, 0.0041384185, 0.02235068, 0.008920949, -0.010112556, -0.01814785, 0.027857836, 0.008317093, -0.048630442, -0.002258417, -0.013357269, -0.00593388, -0.03542615, -0.016328234, -0.012745363, 0.012664848, 0.01463744, -0.012552129, 0.040450223, -0.013260652, 0.039258614, 0.014822623, 0.009226901, 0.006992639, -0.004553065, 0
# ...
